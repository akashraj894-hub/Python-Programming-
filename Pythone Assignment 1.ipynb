# %% [markdown]
# Pythone Assignment 1

# %% [markdown]
# # New Section

# %% [markdown]
# ##1. String Concatenation:

# %%
S="Hello"
Name =input("Enter your Name")

final=S+Name

print(final)
# Out:
# Enter your Name Zara
# Hello Zara

# %%
print(final,",Welcome to python")
# Out:
# Hello Zara ,Welcome to python

# %% [markdown]
# ##2.String Slicing and Indexing:

# %%
A="Hello Zara ,Welcome to python"

A[0]
# Out:
# 'H'

# %%
A[-1]
# Out:
# 'n'

# %%
A[0:5]
# Out:
# 'Hello'

# %%
A[-11: ]
# Out:
# 'e to python'

# %%
A[ : :-1]
# Out:
# 'nohtyp ot emocleW, araZ olleH'

# %%
A[-6: ]
# Out:
# 'python'

# %% [markdown]
# ##3.String Methods:

# %%
strM="Python beginner tutorial"

strM.upper()
# Out:
# 'PYTHON BEGINNER TUTORIAL'

# %%
strM.lower()
# Out:
# 'python beginner tutorial'

# %%
strM.capitalize()
# Out:
# 'Python beginner tutorial'

# %%
strM.count("t")
# Out:
# 3

# %%
strM.replace("Python","Machine Learning")
# Out:
# 'Machine Learning beginner tutorial'

# %% [markdown]
# ##Tuples

# %%
tuple_1=(10,20,30)
tuple_2=(40,50,60)

t_combine=(tuple_1+tuple_2)
print(t_combine)
# Out:
# (10, 20, 30, 40, 50, 60)

# %%
print(t_combine*3)
# Out:
# (10, 20, 30, 40, 50, 60, 10, 20, 30, 40, 50, 60, 10, 20, 30, 40, 50, 60)

# %%
t_combine[2]
# Out:
# 30

# %%
t_combine[0:3]
# Out:
# (10, 20, 30)

# %%
t_combine[-3: ]
# Out:
# (40, 50, 60)

# %%
6%5
# Out:
# 1
